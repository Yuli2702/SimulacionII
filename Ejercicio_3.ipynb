# %% [markdown]
# <a href="https://colab.research.google.com/github/Yuli2702/SimulacionII/blob/main/Ejercicio_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 3**
# Graficar las salidas obtenidas en la Tarea 1

# %%
import random  
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 1, 100)
y = np.sqrt(1 - x**2)     

x_1 = random.random()
y_1 = random.random()

fig = plt.figure(1, figsize=(5, 5))     
plt.plot(x, y, color="pink", markersize=1) 
plt.scatter(x_1, y_1, s=20, c="green")
plt.title("Estimación de $\pi$")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %%
def pi_Taylor(n):
    pi = 0
    L =[]
    for i in range(n):
        pi = pi + 4.0/(2*i+1)*(-1)**i
        L.append(pi)
    fig = plt.figure(1, figsize=(8, 8))        
    plt.plot(L, color="red", markersize=1)
    plt.xlabel("Iteraciones")
    plt.ylabel("Estimación")
    plt.grid()
    plt.show()

# %%
pi_Taylor(200)
